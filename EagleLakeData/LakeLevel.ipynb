# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Lake-Height-Data.txt",
                 sep=",",header=0, 
                 dtype={'CHR_ID': object, 
                         'ELEVATION': np.float64, 
                         'DATUM_ADJ':object},
                         usecols=['ELEVATION','READ_DATE'],
                         parse_dates=[1]
                )

df['YEAR'] = df['READ_DATE'].dt.year
df.set_index("READ_DATE",inplace=True)
df.to_csv("temp.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.relplot(x=df.index, y='ELEVATION',data=df)

# %%
# palette = sns.color_palette("mako_r", 23)
palette = sns.color_palette("husl", 23)
sns.lineplot(x=df.index, y='ELEVATION',data=df,palette=palette,hue="YEAR",linewidth = 3,legend=None)
plt.xlabel('Date')
plt.ylabel('Elevation relative to sealevel (ft)')
plt.title('Eagle Lake Level Relative to Sealevel')
# Out:
# Text(0.5, 1.0, 'Eagle Lake Level Relative to Sealevel')

# %%
df.YEAR.unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022,
#        2023])
